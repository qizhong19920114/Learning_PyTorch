# %% [markdown]
# #### Me Trying to Apply RNN to Name Classification (自己一定要练习一下)
#
# (单独开一个 notebook 好对比)

# %%
import sys
import os

# This is a nice trick to add other python file to this notebook, 这样就挺方便的!!!
# 本质上就是告诉 python interpreter, 你也去看一下我给你添加的这个 file path， 然后正好是我要 import 的那个 path
# 但是这个方法好像有点小问题，就是你 import 的文件改了，你这个kernel 也得 refresh
# "sys.path contains a list of directories that the interpreter will search in for the required module"
#  credit: https://stackoverflow.com/questions/49264194/import-py-file-in-another-directory-in-jupyter-notebook  

# 这里好像非得 join ".." 才行
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "/PyTorch_RNN/pytorch-examples/rnn-name-classification")

# %%
from utils import *
import torch
import torch.nn as nn 
import matplotlib.pyplot as plt

# %%
category_name_map, all_categories = load_data('./pytorch-examples/rnn-name-classification/data/names/*.txt')
n_categories = len(all_categories)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(n_categories)
# Out:
# 18

# %%
class MY_RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(MY_RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)
        
        self.softmax = nn.LogSoftmax(dim=1)
        
    def forward(self, x):

        # num_layers x N x hidden_size
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        
        out, h_n = self.rnn(x, h0)
        
#         print(f"out.size() {out.size()}")
#         print(f"h_n.size() {h_n.size()}")
        
        out = h_n[-1, :, :]

        out = self.fc(out)
        
        out = self.softmax(out)
        
        # 不加这一步， 下面是不是就不用写 output = output.reshape(1, output.size(0))
        # 因为 crossEntropy 期待的就是 n x class_size  的 un-normalized proability array
        # out = out[-1, :]
        # this outputs a size 18 of un-normalized proability array
        return out

# %%
input_size = N_LETTERS
hidden_size = 128
num_classes = n_categories
learning_rate = 0.005

# 应该是可以直接用这个 model 但是 training 的时候注意一下， 因为 seq_len 是 letter len
model = MY_RNN(input_size=input_size, 
               hidden_size=hidden_size, 
               num_layers=1, 
               num_classes=num_classes).to(device)

# %%
# Loss and optimizer
loss_func = nn.NLLLoss()
# loss_func = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# helper function to turn tensor output into a category name
def category_from_output(output):
    #通过 argmax 拿到 softmax output 的最大一个值的 index 然后就可以 look up for item name
    category_idx = torch.argmax(output).item()
    return all_categories[int(category_idx)]

# %%
def train_helper(name_tensor, category_tensor):

    # reshape becaues we have batch_first = true, 所以我得 (batch, seq, feature) 这个 shape
    # 这里 -1 是 default compute 的 word_len 也就是 seq_len
    name_tensor = name_tensor.reshape(1, -1, 57)
    
    output = model(name_tensor)
    # 好像非得把 size 18 转成 1x18 因为CrossEntropyLoss 是期待 n 个 sample (这里只有一个)
    # 然后 probably array of size 18
    # output = output.reshape(1, output.size(0))
#     print(f"output {output}")
 
    #category_tensor = torch.tensor([category_tensor.item()], dtype=torch.long)     
        
#     print(f"category_tensor {category_tensor}")
  
    loss = loss_func(output, category_tensor)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    return output, loss.item()

# %%
# # try a single tensor
# name_tensor = line_to_tensor("abcde")
category, name, category_tensor, name_tensor = random_training_example_with_split(category_name_map, all_categories, False)

# %%
current_loss = 0
all_losses_list = [] #为了后面画图用
plot_steps, print_steps = 1000, 5000
n_iters = 100000 #10000 个 epoch?

print("Iter Iter_Percent Loss Name/Guess Correct")
for i in range(n_iters):
    # category_lines is a category to name list map
    category, name, category_tensor, name_tensor = random_training_example(category_name_map, all_categories)
    
#     print(f"name: {name}")
    
    output, loss = train_helper(name_tensor, category_tensor)
    current_loss += loss 
    
    if (i+1) % plot_steps == 0:
        all_losses_list.append(current_loss / plot_steps)
        current_loss = 0
        
    if (i+1) % print_steps == 0:
        guess = category_from_output(output[0])
        correct = "CORRECT" if guess == category else f"WRONG ({category})"
        print(f"{i+1} {(i+1)/n_iters*100} {loss:.4f} {name} / {guess} {correct}")
        
    
plt.figure()
plt.plot(all_losses_list)
plt.show()
# Out:
# Iter Iter_Percent Loss Name/Guess Correct
# 5000 5.0 2.1212 Yang / Chinese WRONG (Korean)
# 10000 10.0 2.2120 Quigley / English WRONG (Irish)
# 15000 15.0 1.9462 Vicario / Portuguese WRONG (Spanish)
# 20000 20.0 2.4348 Haine / French WRONG (English)
# 25000 25.0 2.4688 Iniguez / Czech WRONG (Spanish)
# 30000 30.0 0.1363 Rossini / Italian CORRECT
# 35000 35.0 2.4391 Kaspar / Arabic WRONG (German)
# 40000 40.0 2.0649 Farrer / German WRONG (English)
# 45000 45.0 0.3391 Yi / Korean CORRECT
# 50000 50.0 0.8195 Melendez / Spanish CORRECT
# 55000 55.00000000000001 2.4492 Rivers / Dutch WRONG (English)
# 60000 60.0 4.6295 Schenck / Czech WRONG (Dutch)
# 65000 65.0 1.7800 Moser / Dutch WRONG (German)
# 70000 70.0 1.6447 Gujavin / Irish WRONG (Russian)
# 75000 75.0 0.0682 Xuan / Chinese CORRECT
# 80000 80.0 1.0355 Rhee / Chinese WRONG (Korean)
# 85000 85.0 0.1410 Travere / French CORRECT
# 90000 90.0 0.0003 Patrianakos / Greek CORRECT
# 95000 95.0 0.7307 Schoonraad / Dutch CORRECT
# 100000 100.0 0.2052 Lando / Italian CORRECT

# %%
# Model Evaluation

total = 1000
n_correct = 0
for i in range(total):
    with torch.no_grad():
        category, name, category_tensor, name_tensor = random_training_example_with_split(category_name_map, all_categories, True)
        guess = model(name_tensor)

        guess = category_from_output(guess[0])
        
        print(f'name {name} guess {guess}, category {category}')
        if(category == guess):
            n_correct+=1
            

print(f'Accuracy {100 * n_correct / total}')
# Out:
# name Yuhno guess English, category Russian
# name Varela guess Russian, category Spanish
# name Yukhvidov guess English, category Russian
# name Rome guess English, category French
# name Satoya guess Korean, category Japanese
# name Villa guess Russian, category Spanish
# name Parrino guess Russian, category Italian
# name Velazquez guess Russian, category Spanish
# name Zanetti guess English, category Italian
# name Zolotnitsky guess English, category Russian
# name Tracey guess Japanese, category Irish
# name Vinh guess Russian, category Vietnamese
# name Totolos guess Japanese, category Greek
# name Torres guess Japanese, category Portuguese
# name Masih guess Korean, category Arabic
# name Kouri guess Korean, category Arabic
# name Yanpolsky guess English, category Russian
# name O'Kelly guess Korean, category Irish
# name Bruce guess Korean, category Scottish
# name Ribeiro guess English, category Portuguese
# name Suero guess Korean, category Spanish
# name Purnell guess Russian, category English
# name Abadi guess Korean, category Arabic
# name Soto guess Korean, category Spanish
# name Simecek guess Korean, category Czech
# name Guo guess Korean, category Chinese
# name Schrader guess Korean, category German
# name Ruzicka guess English, category Czech
# name Naifeh guess Korean, category Arabic
# name Sugden guess Korean, category English
# name Ta guess Japanese, category Vietnamese
# name Yamabe guess English, category Japanese
# name Strohkirch guess Korean, category German
# name Tommii guess Japanese, category Japanese
# name Stauss guess Korean, category German
# name Tsai  guess Japanese, category Korean
# name Sun guess Korean, category Korean
# name Tighearnach guess Japanese, category Irish
# name Somma guess Korean, category Italian
# name Schlimme guess Korean, category German
# name Starek guess Korean, category Polish
# name Sargent guess Korean, category French
# name Sokal guess Korean, category Polish
# name Vlach guess Russian, category Czech
# name V'Yurkov guess Russian, category Russian
# name Whyte guess Korean, category Scottish
# name Sklavenitis guess Korean, category Greek
# name Hay guess English, category Scottish
# name Trang guess Japanese, category Vietnamese
# name Serafim guess Korean, category Portuguese
# name Pesce guess Russian, category Italian
# name Potenza guess Russian, category Italian
# name Tholberg guess Japanese, category Dutch
# name Vyshegorodtsev guess Russian, category Russian
# name Vanwell guess Russian, category English
# name Millar guess Korean, category Scottish
# name You guess English, category Chinese
# name Vargas guess Russian, category Portuguese
# name Zouvelekis guess English, category Greek
# name Voss guess Russian, category German
# name Zolotavin guess English, category Russian
# name Yu guess English, category Korean
# name Tableriou guess Japanese, category Greek
# name Wahner guess Korean, category German
# name Slusarczyk guess Korean, category Polish
# name Slusarczyk guess Korean, category Polish
# name Severins guess Korean, category Dutch
# name Douglas guess Korean, category Scottish
# name Rousses guess English, category Greek
# name Soto guess Korean, category Spanish
# name Tapscott guess Japanese, category English
# name Shimada guess Korean, category Japanese
# name Reyes guess English, category Spanish
# name Vargas guess Russian, category Portuguese
# name Simoes guess Korean, category Portuguese
# name Rapallino guess English, category Italian
# name Ruzicka guess English, category Czech
# name Schermer guess Korean, category Dutch
# name Paternoster guess Russian, category French
# name Villeneuve guess Russian, category French
# name Wang guess Korean, category Korean
# name Plourde guess Russian, category French
# name Zuraw guess English, category Polish
# name Wan guess Korean, category Chinese
# name Snyder guess Korean, category Dutch
# name Tarantino guess Japanese, category Italian
# name Schmied guess Korean, category Czech
# name Samson guess Korean, category Dutch
# name Tungusov guess Japanese, category Russian
# name Vorogushin guess Russian, category Russian
# name Stepan guess Korean, category Czech
# name Viteri guess Russian, category Spanish
# name Papadopulos guess Russian, category Greek
# name Sui guess Korean, category Chinese
# name Tsai  guess Japanese, category Korean
# name Song guess Korean, category Korean
# name Wei guess Korean, category German
# name Rompaeij guess English, category Dutch
# name Reyer guess English, category French
# name Trinh guess Japanese, category Vietnamese
# name Ramires guess English, category Portuguese
# name Schoorel guess Korean, category Dutch
# name Rivkin guess English, category Russian
# name Rompu guess English, category Dutch
# name Tsai  guess Japanese, category Korean
# name Yeon guess English, category Korean
# name Rendon guess English, category Spanish
# name Sugawara guess Korean, category Japanese
# name Totah guess Japanese, category Arabic
# name Zhezhel guess English, category Russian
# name Tovstukha guess Japanese, category Russian
# name Wyer guess Korean, category English
# name Wakatsuki guess Korean, category Japanese
# name Vikhansky guess Russian, category Russian
# name Bing guess Korean, category Chinese
# name Asfour guess Korean, category Arabic
# name Tong guess Japanese, category Vietnamese
# name Riain guess English, category Irish
# name Zhao guess English, category Chinese
# name Salamanca guess Korean, category Spanish
# name Rustici guess English, category Italian
# name Smit guess Korean, category Dutch
# name Tyrrell guess Japanese, category English
# name Starek guess Korean, category Polish
# name Pozzi guess Russian, category Italian
# name Silva guess Korean, category Portuguese
# name Stangl guess Korean, category Czech
# name Silveira guess Korean, category Portuguese
# name Takamura guess Japanese, category Japanese
# name Hajjar guess English, category Arabic
# name Thai guess Japanese, category Vietnamese
# name Porcher guess Russian, category French
# name Ruadhain guess English, category Irish
# name Mcgregor guess Korean, category Scottish
# name Roosevelt guess English, category Dutch
# name Tawaraya guess Japanese, category Japanese
# name Sardelis guess Korean, category Greek
# name Ryskamp guess English, category Dutch
# name Thach guess Japanese, category Vietnamese
# name Tsutaya guess Japanese, category Japanese
# name Schubert guess Korean, category Czech
# name Fleming guess English, category Scottish
# name Wei guess Korean, category German
# name Tilley guess Japanese, category English
# name Sowka guess Korean, category Polish
# name Thai guess Japanese, category Vietnamese
# name Saller guess Korean, category German
# name Mccallum guess Korean, category Scottish
# name Twiggs guess Japanese, category English
# name Zherebin guess English, category Russian
# name Soares guess Korean, category Portuguese
# name Sasada guess Korean, category Japanese
# name Christie guess Russian, category Scottish
# name Zhelezovsky guess English, category Russian
# name Sanna guess Korean, category Dutch
# name Quiros guess Korean, category Spanish
# name Raghailligh guess English, category Irish
# name Sun guess Korean, category Korean
# name Storer guess Korean, category English
# name Vives guess Russian, category Spanish
# name Werner guess Korean, category German
# name Thai guess Japanese, category Vietnamese
# name Salomon guess Korean, category German
# name Szweda guess Korean, category Polish
# name Stark guess Korean, category English
# name Rann guess English, category English
# name Son guess Korean, category Korean
# name Si guess Korean, category Korean
# name Seegers guess Korean, category Dutch
# name Sniders guess Korean, category Dutch
# name Khoury guess Korean, category Arabic
# name Vainer guess Russian, category Russian
# name Poingdestre guess Russian, category French
# name Vassilopulos guess Russian, category Greek
# name Satorie guess Korean, category Czech
# name Timpe guess Japanese, category Czech
# name Szwedko guess Korean, category Polish
# name Schneider guess Korean, category Czech
# name Sokolof guess Korean, category Polish
# name Schuler guess Korean, category German
# name Shuo guess Korean, category Chinese
# name Timpe guess Japanese, category Czech
# name Takizawa guess Japanese, category Japanese
# name Quyen guess Korean, category Vietnamese
# name Ghanem guess Korean, category Arabic
# name Srpcikova guess Korean, category Czech
# name Stanek guess Korean, category Polish
# name Yoo guess English, category Korean
# name Vargas guess Russian, category Spanish
# name Takeshita guess Japanese, category Japanese
# name Sneijer guess Korean, category Dutch
# name Stites guess Korean, category Czech
# name Taverna guess Japanese, category Italian
# name Toma guess Japanese, category Arabic
# name Song guess Korean, category Korean
# name Quinn guess Korean, category Irish
# name Szczepanski guess Korean, category Polish
# name Rompuy guess English, category Dutch
# name Proulx guess Russian, category French
# name Silcock guess Korean, category English
# name Travere guess Japanese, category French
# name Zhui guess English, category Chinese
# name Pinheiro guess Russian, category Portuguese
# name Povey guess Russian, category English
# name Thai guess Japanese, category Vietnamese
# name Quigley guess Korean, category Irish
# name Tzekhansky guess Japanese, category Russian
# name Sankovsky guess Korean, category Czech
# name Paraskos guess Russian, category Greek
# name Fleming guess English, category Scottish
# name Roma guess English, category Spanish
# name Piccoli guess Russian, category Italian
# name Yoshihara guess English, category Japanese
# name Yoshikawa guess English, category Japanese
# name Tsalko guess Japanese, category Russian
# name Patenaude guess Russian, category French
# name Tunison guess Japanese, category Dutch
# name Parent guess Russian, category French
# name Bruce guess Korean, category Scottish
# name Malouf guess Korean, category Arabic
# name Stawski guess Korean, category Polish
# name Touma guess Japanese, category Arabic
# name Zong guess English, category Chinese
# name Tomori guess Japanese, category Japanese
# name William guess Korean, category Irish
# name Segal guess Korean, category French
# name Simodines guess Korean, category Czech
# name Zielinski guess English, category Polish
# name Villeneuve guess Russian, category French
# name Showell guess Korean, category English
# name Vinh guess Russian, category Vietnamese
# name Waters guess Korean, category English
# name Naifeh guess Korean, category Arabic
# name Traver guess Japanese, category French
# name Tassioglou guess Japanese, category Greek
# name Sakelaris guess Korean, category Greek
# name Xydis guess Korean, category Greek
# name Thach guess Japanese, category Vietnamese
# name Villiger guess Russian, category English
# name Swatchak guess Korean, category Czech
# name Thomson guess Japanese, category English
# name Polymenakou guess Russian, category Greek
# name Schulthei guess Korean, category German
# name Tong guess Japanese, category Vietnamese
# name Romagna guess English, category Italian
# name Tieu guess Japanese, category Vietnamese
# name Smit guess Korean, category English
# name Semick guess Korean, category Czech
# name Stoppelbein guess Korean, category German
# name Rixon guess English, category English
# name Spyridis guess Korean, category Greek
# name Schreck guess Korean, category German
# name Vestri guess Russian, category Italian
# name Ruadhan guess English, category Irish
# name Vourlis guess Russian, category Greek
# name Severins guess Korean, category Dutch
# name Riagan guess English, category Irish
# name Robert guess English, category French
# name Van guess Russian, category Vietnamese
# name Vitruk guess Russian, category Russian
# name Proulx guess Russian, category French
# name Rosario guess English, category Portuguese
# name Zhang guess English, category Chinese
# name Bazzi guess Korean, category Arabic
# name Schoorl guess Korean, category Dutch
# name Roy guess English, category French
# name Walentowicz guess Korean, category Polish
# name Tieu guess Japanese, category Vietnamese
# name Guan guess Korean, category Chinese
# name Rey guess English, category Spanish
# name Southwick guess Korean, category English
# name Sekovora guess Korean, category Czech
# name Truhachev guess Japanese, category Russian
# name Santos guess Korean, category Portuguese
# name To guess Japanese, category Vietnamese
# name Shiratori guess Korean, category Japanese
# name Sitz guess Korean, category German
# name Qing guess Korean, category Chinese
# name Roldan guess English, category Spanish
# name Mccallum guess Korean, category Scottish
# name Sastre guess Korean, category Spanish
# name Schneijder guess Korean, category Dutch
# name Von ingersleben guess Russian, category German
# name Wood guess Korean, category Czech
# name Docherty guess Korean, category Scottish
# name Yun guess English, category Korean
# name Woo guess Korean, category Korean
# name Stramba guess Korean, category Czech
# name Lindsay guess Korean, category Scottish
# name Stramba guess Korean, category Czech
# name Yu guess English, category Korean
# name Sciacca guess Korean, category Italian
# name Valenti guess Russian, category Italian
# name Rompaij guess English, category Dutch
# name Sebastino guess Korean, category Italian
# name Veverka guess Russian, category Czech
# name Robishaw guess English, category English
# name Villalobos guess Russian, category Spanish
# name Serejnikov guess Korean, category Russian
# name Vela guess Russian, category Spanish
# name Zang guess English, category Chinese
# name Terzi guess Japanese, category Italian
# name Schlender guess Korean, category German
# name Quyen guess Korean, category Vietnamese
# name Si guess Korean, category Korean
# name Rizzo guess English, category Italian
# name Shirko guess Korean, category Russian
# name Senmatsu guess Korean, category Japanese
# name Stuber guess Korean, category German
# name Mcgregor guess Korean, category Scottish
# name Tobias guess Japanese, category French
# name Vigo guess Russian, category Italian
# name Thach guess Japanese, category Vietnamese
# name Arian guess Korean, category Arabic
# name Takewaki guess Japanese, category Japanese
# name Gai guess Korean, category Chinese
# name Chi guess Russian, category Chinese
# name Schulz guess Korean, category German
# name Vlasek guess Russian, category Czech
# name Whelan guess Korean, category Irish
# name Riagain guess English, category Irish
# name Tobias guess Japanese, category French
# name Teagan guess Japanese, category Irish
# name Naifeh guess Korean, category Arabic
# name Traverse guess Japanese, category French
# name Samuel guess Korean, category French
# name Rakhmatullin guess English, category Russian
# name Tahan guess Japanese, category Arabic
# name Harb guess English, category Arabic
# name Thuy guess Japanese, category Vietnamese
# name O'Hare guess Korean, category Irish
# name Zabek guess English, category Polish
# name Santos guess Korean, category Portuguese
# name Taniguchi guess Japanese, category Japanese
# name Weichert guess Korean, category Czech
# name Sabol guess Korean, category Czech
# name O'Loughlin guess Korean, category Irish
# name Smit guess Korean, category Dutch
# name Suarez guess Korean, category Spanish
# name Millar guess Korean, category Scottish
# name Romao guess English, category Portuguese
# name Roach guess English, category Irish
# name Torrens guess Japanese, category English
# name Samios guess Korean, category Greek
# name Yoon guess English, category Korean
# name Sokoloff guess Korean, category Polish
# name Van guess Russian, category Vietnamese
# name Szczepanski guess Korean, category Polish
# name Tai guess Japanese, category Chinese
# name Torres guess Japanese, category Spanish
# name Zhimila guess English, category Russian
# name Shim guess Korean, category Korean
# name Schuyler guess Korean, category Dutch
# name Schoorel guess Korean, category Dutch
# name O'Mahoney guess Korean, category Irish
# name Sook guess Korean, category Korean
# name Sowka guess Korean, category Polish
# name Sarna guess Korean, category Czech
# name Schmitt guess Korean, category German
# name Schroeter guess Korean, category German
# name Santana guess Korean, category Portuguese
# name Tyman guess Japanese, category English
# name Teunissen guess Japanese, category Dutch
# name Samson guess Korean, category Dutch
# name West guess Korean, category German
# name Rollinson guess English, category English
# name Serafim guess Korean, category Portuguese
# name Thake guess Japanese, category English
# name Aitken guess Korean, category Scottish
# name Umehara guess Czech, category Japanese
# name Tokaji guess Japanese, category Japanese
# name Whelan guess Korean, category Irish
# name Mccallum guess Korean, category Scottish
# name Sakellariou guess Korean, category Greek
# name Kanaan guess Korean, category Arabic
# name Rodrigues guess English, category Portuguese
# name Pinheiro guess Russian, category Portuguese
# name Von essen guess Russian, category German
# name Schmidt guess Korean, category German
# name Vozdvijensky guess Russian, category Russian
# name Taketomo guess Japanese, category Japanese
# name Tobias guess Japanese, category French
# name Handal guess English, category Arabic
# name Liang guess Korean, category Chinese
# name Vinh guess Russian, category Vietnamese
# name Varvitsiotes guess Russian, category Greek
# name Yankilevsky guess English, category Russian
# name Said guess Korean, category Arabic
# name Son guess Korean, category Korean
# name Patrick guess Russian, category Irish
# name Theunissen guess Japanese, category Dutch
# name Perreault guess Russian, category French
# name Shimura guess Korean, category Japanese
# name Trampotova guess Japanese, category Czech
# name Paraskos guess Russian, category Greek
# name Starek guess Korean, category Polish
# name Whelan guess Korean, category Irish
# name Rocha guess English, category Portuguese
# name Szewc guess Korean, category Polish
# name Roche guess English, category French
# name Mifsud guess Korean, category Arabic
# name O'Kelly guess Korean, category Irish
# name Rossem guess English, category Dutch
# name Hill guess English, category Scottish
# name Rosario guess English, category Portuguese
# name Pisani guess Russian, category Italian
# name Samaha guess Korean, category Arabic
# name Seighin guess Korean, category Irish
# name O'Ryan guess Korean, category Irish
# name Szczepanski guess Korean, category Polish
# name Uzenya guess Czech, category Russian
# name Tieu guess Japanese, category Vietnamese
# name Uhlik guess Czech, category Czech
# name Russov guess English, category Russian
# name Werner guess Korean, category German
# name Vargas guess Russian, category Portuguese
# name Spicka guess Korean, category Czech
# name You guess English, category Chinese
# name Soma guess Korean, category Japanese
# name Unruh guess Czech, category German
# name Sai guess Korean, category Vietnamese
# name Youj guess English, category Korean
# name Rompu guess English, category Dutch
# name Guo guess Korean, category Chinese
# name Wan guess Korean, category Chinese
# name Takemitsu guess Japanese, category Japanese
# name Skala guess Korean, category Czech
# name Usami guess Czech, category Japanese
# name Thayer guess Japanese, category French
# name Pezos guess Russian, category Greek
# name Jackson guess English, category Scottish
# name Siegl guess Korean, category Czech
# name Simoes guess Korean, category Portuguese
# name Paquet guess Russian, category French
# name Register guess English, category Irish
# name To guess Japanese, category Vietnamese
# name San nicolas guess Korean, category Spanish
# name Ruzicka guess English, category Czech
# name StrakaO guess Korean, category Czech
# name Sakellariou guess Korean, category Greek
# name Sauber guess Korean, category German
# name Sniegowski guess Korean, category Polish
# name Ricchetti guess English, category Italian
# name Romero guess English, category Spanish
# name Sniders guess Korean, category Dutch
# name Patton guess Russian, category English
# name Sauvageau guess Korean, category French
# name Kuai guess Korean, category Chinese
# name Parkin guess Russian, category English
# name Thach guess Japanese, category Vietnamese
# name Yadryshnikov guess English, category Russian
# name Vuu guess Russian, category Vietnamese
# name Yuan guess English, category Chinese
# name Reyer guess English, category French
# name Salcedo guess Korean, category Spanish
# name Ustinkin guess Czech, category Russian
# name Raimondi guess English, category Italian
# name Tornincasa guess Japanese, category Italian
# name Rhys guess English, category Irish
# name Tsahalis guess Japanese, category Greek
# name Mcintosh guess Korean, category Scottish
# name Maloof guess Korean, category Arabic
# name Xin guess Korean, category Chinese
# name Ybarra guess English, category Spanish
# name Reyer guess English, category French
# name Zhuan guess English, category Chinese
# name Travers guess Japanese, category French
# name Vamvakidis guess Russian, category Greek
# name Vicario guess Russian, category Italian
# name Ronchi guess English, category Italian
# name Poingdestre guess Russian, category French
# name Wang guess Korean, category Korean
# name Yushnevsky guess English, category Russian
# name Simmons guess Korean, category English
# name Vargas guess Russian, category Portuguese
# name Zeng guess English, category Chinese
# name Tilson guess Japanese, category English
# name Trnkova guess Japanese, category Czech
# name Pharlain guess Russian, category Irish
# name Satoya guess Korean, category Japanese
# name Santos guess Korean, category Portuguese
# name Ter Avest guess Japanese, category Dutch
# name Vuu guess Russian, category Vietnamese
# name Shigemitsu guess Korean, category Japanese
# name Were guess Korean, category English
# name Richman guess English, category English
# name Portyanko guess Russian, category Russian
# name Ruadhain guess English, category Irish
# name Shon guess Korean, category Korean
# name Aswad guess Korean, category Arabic
# name Tyler guess Japanese, category English
# name Vihirev guess Russian, category Russian
# name Reyes guess English, category Spanish
# name Watoga guess Korean, category Japanese
# name Maclean guess Korean, category Scottish
# name Vargas guess Russian, category Spanish
# name Sui guess Korean, category Chinese
# name Ventura guess Russian, category Portuguese
# name Waldfogel guess Korean, category German
# name Sin guess Korean, category Korean
# name Roma guess English, category Spanish
# name Suk guess Korean, category Korean
# name Takagaki guess Japanese, category Japanese
# name Boyle guess Korean, category Scottish
# name Rey guess English, category Spanish
# name Petimezas guess Russian, category Greek
# name Raghailligh guess English, category Irish
# name Tahan guess Japanese, category Arabic
# name Someya guess Korean, category Japanese
# name Silje guess Korean, category Dutch
# name Youj guess English, category Korean
# name Silveira guess Korean, category Portuguese
# name Tong guess Japanese, category Vietnamese
# name Powles guess Russian, category English
# name Steel guess Korean, category English
# name Ryskamp guess English, category Dutch
# name Sommer guess Korean, category German
# name Steffen guess Korean, category German
# name Santos guess Korean, category Portuguese
# name Schubert guess Korean, category German
# name Walentowicz guess Korean, category Polish
# name Zhao guess English, category Chinese
# name You guess English, category Korean
# name Rios guess English, category Portuguese
# name Schermer guess Korean, category Dutch
# name Sokolowski guess Korean, category Polish
# name Ba guess Korean, category Arabic
# name Mccallum guess Korean, category Scottish
# name Suzuki guess Korean, category Japanese
# name Smolak guess Korean, category Polish
# name Sakellariou guess Korean, category Greek
# name Shaitan guess Korean, category Russian
# name Romeijnsen guess English, category Dutch
# name Tellis guess Japanese, category English
# name King guess Korean, category Scottish
# name Koury guess Korean, category Arabic
# name Traverse guess Japanese, category French
# name Sabbagh guess Korean, category Arabic
# name Jones guess English, category Scottish
# name Spannagel guess Korean, category German
# name Ton guess Japanese, category Vietnamese
# name Tahan guess Japanese, category Arabic
# name Yu guess English, category Korean
# name Silva guess Korean, category Portuguese
# name Tremblay guess Japanese, category French
# name Salcedo guess Korean, category Spanish
# name Sun guess Korean, category Korean
# name Mcintyre guess Korean, category Scottish
# name Schultes guess Korean, category German
# name Walter guess Korean, category English
# name Quiros guess Korean, category Spanish
# name Shibaguchi guess Korean, category Japanese
# name Pefanis guess Russian, category Greek
# name Fakhoury guess English, category Arabic
# name Vitali guess Russian, category Italian
# name Snider guess Korean, category Dutch
# name Sardelis guess Korean, category Greek
# name Vieth guess Russian, category German
# name Robert guess English, category French
# name Spada guess Korean, category Italian
# name Docherty guess Korean, category Scottish
# name Somma guess Korean, category Italian
# name Roux guess English, category French
# name Register guess English, category Irish
# name Zdunowski guess English, category Polish
# name Santiago guess Korean, category Portuguese
# name Schmid guess Korean, category German
# name Yang guess English, category Korean
# name Nao guess Korean, category Chinese
# name Perowne guess Russian, category English
# name Alexander guess Korean, category Scottish
# name Samson guess Korean, category French
# name Samson guess Korean, category French
# name Vinci guess Russian, category Italian
# name Hughes guess English, category Scottish
# name Urbina guess Czech, category Spanish
# name Sullivan guess Korean, category Irish
# name Vann guess Russian, category Dutch
# name Romagna guess English, category Italian
# name Ribeiro guess English, category Portuguese
# name Yim guess English, category Korean
# name Rang guess English, category Chinese
# name O'Hare guess Korean, category Irish
# name Rhys guess English, category Irish
# name Tong guess Japanese, category Vietnamese
# name Boyle guess Korean, category Scottish
# name Svotchak guess Korean, category Czech
# name Sartre guess Korean, category French
# name Sook guess Korean, category Korean
# name Wyman guess Korean, category German
# name Salazar guess Korean, category Portuguese
# name Tsaran guess Japanese, category Russian
# name Kalb guess Korean, category Arabic
# name Ufimov guess Czech, category Russian
# name Smets guess Korean, category Dutch
# name Paternoster guess Russian, category French
# name Santos guess Korean, category Portuguese
# name Teagan guess Japanese, category Irish
# name Ramsay guess English, category Scottish
# name Thach guess Japanese, category Vietnamese
# name Vourlis guess Russian, category Greek
# name Rios guess English, category Portuguese
# name Simodines guess Korean, category Czech
# name Zdunowski guess English, category Polish
# name Kuai guess Korean, category Chinese
# name Sung guess Korean, category Korean
# name Skwor guess Korean, category Czech
# name Richelieu guess English, category French
# name Porcher guess Russian, category French
# name Vlach guess Russian, category Czech
# name Shon guess Korean, category Korean
# name Pini guess Russian, category Italian
# name Yoon guess English, category Korean
# name Segers guess Korean, category Dutch
# name Urbina guess Czech, category Spanish
# name Seegers guess Korean, category Dutch
# name Rian guess English, category Irish
# name Yue guess English, category Chinese
# name Sullivan guess Korean, category Irish
# name Starek guess Korean, category Polish
# name Simoes guess Korean, category Portuguese
# name Boutros guess Korean, category Arabic
# name Skokan guess Korean, category Czech
# name Romijnsen guess English, category Dutch
# name Wyrick guess Korean, category Polish
# name Speziale guess Korean, category Italian
# name Sortras guess Korean, category Greek
# name Trollope guess Japanese, category English
# name Re guess English, category Italian
# name Silverstein guess Korean, category German
# name Zapatero guess English, category Spanish
# name Telis guess Japanese, category Greek
# name Rorris guess English, category Greek
# name Yakunkin guess English, category Russian
# name Ramires guess English, category Portuguese
# name Weiman guess Korean, category German
# name Seelen guess Korean, category Dutch
# name Rahal guess English, category Arabic
# name Yang guess English, category Korean
# name Shalhoub guess Korean, category Arabic
# name Yukhtanov guess English, category Russian
# name Trieu guess Japanese, category Vietnamese
# name O'Hara guess Korean, category Irish
# name Sachs guess Korean, category German
# name Boyle guess Korean, category Scottish
# name Wyrzyk guess Korean, category Polish
# name Thi guess Japanese, category Vietnamese
# name Ribeiro guess English, category Portuguese
# name Vassilikos guess Russian, category Greek
# name Sen guess Korean, category Japanese
# name Sommer guess Korean, category German
# name Shige guess Korean, category Japanese
# name Travieso guess Japanese, category Spanish
# name Tailler guess Japanese, category French
# name Romagna guess English, category Italian
# name Turkov guess Japanese, category Russian
# name St martin guess Korean, category French
# name Suarez guess Korean, category Spanish
# name Zhevahov guess English, category Russian
# name Pearce guess Russian, category English
# name Vogts guess Russian, category German
# name Docherty guess Korean, category Scottish
# name Patrick guess Russian, category Irish
# name Crawford guess Russian, category Scottish
# name Reddy guess English, category English
# name Samson guess Korean, category Dutch
# name Mcintosh guess Korean, category Scottish
# name Sklavenitis guess Korean, category Greek
# name Sullivan guess Korean, category Irish
# name Tully guess Japanese, category English
# name Parent guess Russian, category French
# name Wyman guess Korean, category German
# name Mcgregor guess Korean, category Scottish
# name Svejda guess Korean, category Czech
# name Percival guess Russian, category English
# name Ventura guess Russian, category Portuguese
# name Mclaughlin guess Korean, category Scottish
# name Zhukovets guess English, category Russian
# name Paquet guess Russian, category French
# name Specht guess Korean, category German
# name Ribeiro guess English, category Portuguese
# name Rypka guess English, category Czech
# name Theunissen guess Japanese, category Dutch
# name Rios guess English, category Portuguese
# name Teshima guess Japanese, category Japanese
# name Romijnders guess English, category Dutch
# name Schmied guess Korean, category Czech
# name Simoes guess Korean, category Portuguese
# name Turke guess Japanese, category English
# name Schoorel guess Korean, category Dutch
# name Sims guess Korean, category English
# name Varvitsiotes guess Russian, category Greek
# name Mcgregor guess Korean, category Scottish
# name Zheglov guess English, category Russian
# name Quyen guess Korean, category Vietnamese
# name Rompa guess English, category Dutch
# name Tuma guess Japanese, category Arabic
# name Pezos guess Russian, category Greek
# name Zhelyabuzhsky guess English, category Russian
# name Thuy guess Japanese, category Vietnamese
# name Mcintosh guess Korean, category Scottish
# name Shuo guess Korean, category Chinese
# name Sklavenitis guess Korean, category Greek
# name Petimezas guess Russian, category Greek
# name Parma guess Russian, category Italian
# name Tosell guess Japanese, category Spanish
# name Urogataya guess Czech, category Japanese
# name Sokolowski guess Korean, category Polish
# name Ziemniak guess English, category Polish
# name Tschida guess Japanese, category German
# name Salvail guess Korean, category Italian
# name Hay guess English, category Scottish
# name Yun guess English, category Korean
# name Theunissen guess Japanese, category Dutch
# name Xie guess Korean, category Chinese
# name Yue guess English, category Chinese
# name Tcharukhin guess Japanese, category Russian
# name Sokal guess Korean, category Polish
# name Shiraishi guess Korean, category Japanese
# name Santana guess Korean, category Spanish
# name Tsahalis guess Japanese, category Greek
# name Parris guess Russian, category French
# name Villeneuve guess Russian, category French
# name Sierra guess Korean, category Spanish
# name Rosario guess English, category Portuguese
# name Youj guess English, category Korean
# name Theunissen guess Japanese, category Dutch
# name Zhang guess English, category Chinese
# name Millar guess Korean, category Scottish
# name Yun guess English, category Korean
# name Trang guess Japanese, category Vietnamese
# name Trang guess Japanese, category Vietnamese
# name Rios guess English, category Portuguese
# name Youn guess English, category Korean
# name Tai guess Japanese, category Chinese
# name Ying guess English, category Chinese
# name Parent guess Russian, category French
# name Phocas guess Russian, category Greek
# name Sevriens guess Korean, category Dutch
# name Zhang guess English, category Chinese
# name Samz guess Korean, category Czech
# name Tolkien guess Japanese, category German
# name Antar guess Korean, category Arabic
# name Salazar guess Korean, category Portuguese
# name Whyte guess Korean, category Scottish
# name Rowe guess English, category English
# name Dan guess Korean, category Chinese
# name Shaw guess Korean, category Scottish
# name Sedmik guess Korean, category Czech
# name Silveira guess Korean, category Portuguese
# name Telis guess Japanese, category Greek
# name Vargas guess Russian, category Portuguese
# name Truong guess Japanese, category Vietnamese
# name Topham guess Japanese, category English
# name Wolter guess Korean, category German
# name Scheinberg guess Korean, category German
# name Ying guess English, category Chinese
# name Riggi guess English, category Italian
# name Sechnall guess Korean, category Irish
# name Serafim guess Korean, category Portuguese
# name Schenck guess Korean, category Dutch
# name Santiago guess Korean, category Portuguese
# name Roux guess English, category French
# name Portoghese guess Russian, category Italian
# name Sedmikova guess Korean, category Czech
# name Yamaoka guess English, category Japanese
# name Santos guess Korean, category Portuguese
# name Schepotkin guess Korean, category Russian
# name Vandroogenbroeck guess Russian, category Dutch
# name Wan guess Korean, category Chinese
# name Wojewodzki guess Korean, category Polish
# name Steen guess Korean, category German
# name Song guess Korean, category Korean
# name Sai guess Korean, category Vietnamese
# name Yeo guess English, category Korean
# name Seaghdha guess Korean, category Irish
# name Douglas guess Korean, category Scottish
# name Roig guess English, category Spanish
# name Yasuhiro guess English, category Japanese
# name Svejkovsky guess Korean, category Czech
# name Yasuda guess English, category Japanese
# name Tieu guess Japanese, category Vietnamese
# name Poniros guess Russian, category Greek
# name Pascal guess Russian, category French
# name Trinh guess Japanese, category Vietnamese
# name Whittley guess Korean, category English
# name Sula guess Korean, category Czech
# name Toyotomi guess Japanese, category Japanese
# name Christie guess Russian, category Scottish
# name Schenck guess Korean, category Dutch
# name Wood guess Korean, category Czech
# name Zhi guess English, category Chinese
# name Schorel guess Korean, category Dutch
# name Savchak guess Korean, category Czech
# name Terranova guess Japanese, category Italian
# name Zha guess English, category Chinese
# name Protopsaltis guess Russian, category Greek
# name Yakubenko guess English, category Russian
# name Ruggeri guess English, category Italian
# name Lindsay guess Korean, category Scottish
# name Papageorge guess Russian, category Greek
# name Gaber guess Korean, category Arabic
# name Sarraf guess Korean, category Arabic
# name Moghadam guess Korean, category Arabic
# name Vaccaro guess Russian, category Italian
# name Ruadhan guess English, category Irish
# name Tracey guess Japanese, category Irish
# name Zong guess English, category Chinese
# name Zabala guess English, category Spanish
# name Douglas guess Korean, category Scottish
# name Perkins guess Russian, category English
# name Shon guess Korean, category Korean
# name Xing guess Korean, category Chinese
# name Sauvageau guess Korean, category French
# name Xing guess Korean, category Chinese
# name Shim guess Korean, category Korean
# name Zilberschlag guess English, category German
# name Boyle guess Korean, category Scottish
# name Thompson guess Japanese, category English
# name Sitz guess Korean, category German
# name Wyrzyk guess Korean, category Polish
# name Rick guess English, category English
# name Rossum guess English, category Dutch
# name Von brandt guess Russian, category German
# name Ramirez guess English, category Spanish
# name Truong guess Japanese, category Vietnamese
# name Ruiz guess English, category Spanish
# name Tassioglou guess Japanese, category Greek
# name Saikin guess Korean, category Russian
# name Poletti guess Russian, category Italian
# name Shionoya guess Korean, category Japanese
# name Mcintyre guess Korean, category Scottish
# name Schreck guess Korean, category German
# name Taverna guess Japanese, category Italian
# name Riggi guess English, category Italian
# name Thai guess Japanese, category Vietnamese
# name Totah guess Japanese, category Arabic
# name Silva guess Korean, category Portuguese
# name Wojda guess Korean, category Polish
# name Vinh guess Russian, category Vietnamese
# name Shin guess Korean, category Korean
# name Sankovsky guess Korean, category Czech
# name Soares guess Korean, category Portuguese
# name Santiago guess Korean, category Portuguese
# name Tsalko guess Japanese, category Russian
# name Sauvageot guess Korean, category French
# name Rosa guess English, category Spanish
# name Solos guess Korean, category Spanish
# name Stavropoulos guess Korean, category Greek
# name Yamakage guess English, category Japanese
# name Tong guess Japanese, category Vietnamese
# name Guo guess Korean, category Chinese
# name Vescovi guess Russian, category Italian
# name Whelan guess Korean, category Irish
# name Petit guess Russian, category French
# name Ricci guess English, category Italian
# name Sobol guess Korean, category Polish
# name Rose guess English, category French
# name Rorris guess English, category Greek
# name Sokolowski guess Korean, category Polish
# name Rosario guess English, category Portuguese
# name Sarkozy guess Korean, category French
# name Wojewodka guess Korean, category Polish
# name Savatier guess Korean, category French
# name Santana guess Korean, category Portuguese
# name Silveira guess Korean, category Portuguese
# name Wendell guess Korean, category German
# name Zapatero guess English, category Spanish
# name Rocha guess English, category Portuguese
# name Hughes guess English, category Scottish
# name Wruck guess Korean, category German
# name Scheblykin guess Korean, category Russian
# name Tong guess Japanese, category Vietnamese
# name Vinci guess Russian, category Italian
# name Sotiris guess Korean, category Greek
# name Valenti guess Russian, category Italian
# name Wojda guess Korean, category Polish
# name Szweda guess Korean, category Polish
# name Yeatman guess English, category English
# name Romijn guess English, category Dutch
# name Whyte guess Korean, category Scottish
# name Shenderovich guess Korean, category Russian
# name Sepulveda guess Korean, category Spanish
# name Tumicelli guess Japanese, category Italian
# name Wolff guess Korean, category German
# name Ton guess Japanese, category Vietnamese
# name Schoonraad guess Korean, category Dutch
# name Smits guess Korean, category Dutch
# name Segal guess Korean, category French
# name Wyrick guess Korean, category Polish
# name Sorrentino guess Korean, category Italian
# name Sobol guess Korean, category Polish
# name Sotiris guess Korean, category Greek
# name Utton guess Czech, category English
# name Samson guess Korean, category French
# name Shin guess Korean, category Korean
# name Tieu guess Japanese, category Vietnamese
# name Bing guess Korean, category Chinese
# name Zhi guess English, category Chinese
# name Toomey guess Japanese, category English
# name Ugaki guess Czech, category Japanese
# name Rotolo guess English, category Italian
# name Douglas guess Korean, category Scottish
# name Wetzel guess Korean, category German
# name Zientek guess English, category Polish
# name Douglas guess Korean, category Scottish
# name Peatain guess Russian, category Irish
# name Son guess Korean, category Korean
# name Rickard guess English, category English
# name Vassilopulos guess Russian, category Greek
# name Ta guess Japanese, category Vietnamese
# name Schorel guess Korean, category Dutch
# name Wiltshire guess Korean, category English
# name Takagaki guess Japanese, category Japanese
# name Wateridge guess Korean, category English
# name Takeshita guess Japanese, category Japanese
# name Stangl guess Korean, category Czech
# name Thi guess Japanese, category Vietnamese
# name Maclean guess Korean, category Scottish
# name Sokolsky guess Korean, category Polish
# name O'Leary guess Korean, category Irish
# name Polymenakou guess Russian, category Greek
# name Pisani guess Russian, category Italian
# name Ramires guess English, category Portuguese
# name Powis guess Russian, category English
# name Tsogas guess Japanese, category Greek
# name Shalimo guess Korean, category Russian
# name Poirier guess Russian, category French
# name Schuyler guess Korean, category Dutch
# name Sandoval guess Korean, category Spanish
# name Tong guess Japanese, category Vietnamese
# name Tadhgan guess Japanese, category Irish
# name Schroder guess Korean, category German
# name Tsakul guess Japanese, category Russian
# name Yasui guess English, category Japanese
# name Sun guess Korean, category Korean
# name Sharp guess Korean, category English
# name Schenck guess Korean, category Dutch
# name Tsai  guess Japanese, category Korean
# name Terrazas guess Japanese, category Spanish
# name Sklavenitis guess Korean, category Greek
# name Sin guess Korean, category Korean
# name Wilcox guess Korean, category English
# name Von brandt guess Russian, category German
# name Pinheiro guess Russian, category Portuguese
# name Yoo guess English, category Korean
# name Quinn guess Korean, category Irish
# name Yeo guess English, category Korean
# name Paraskos guess Russian, category Greek
# name Christie guess Russian, category Scottish
# name Soukup guess Korean, category Czech
# name Rosa guess English, category Spanish
# name Tsai  guess Japanese, category Korean
# name Silveira guess Korean, category Portuguese
# name Stramba guess Korean, category Czech
# name Shige guess Korean, category Japanese
# name Sun guess Korean, category Korean
# name Sanchez guess Korean, category Spanish
# name Yorke guess English, category English
# name Malouf guess Korean, category Arabic
# name Rocha guess English, category Portuguese
# name Sokal guess Korean, category Polish
# name Zhuan guess English, category Chinese
# name Trang guess Japanese, category Vietnamese
# name Thach guess Japanese, category Vietnamese
# name Vamvakidis guess Russian, category Greek
# name Quyen guess Korean, category Vietnamese
# name Santana guess Korean, category Portuguese
# name Docherty guess Korean, category Scottish
# name Sugisata guess Korean, category Japanese
# name Uhov guess Czech, category Russian
# name Gerges guess Korean, category Arabic
# name Thi guess Japanese, category Vietnamese
# name Vasquez guess Russian, category Spanish
# name Zaruba guess English, category Czech
# name Sokolof guess Korean, category Polish
# name Yang guess English, category Korean
# name Winograd guess Korean, category Polish
# name Van guess Russian, category Vietnamese
# name Sokolik guess Korean, category Czech
# name Vacca guess Russian, category Italian
# name Papageorge guess Russian, category Greek
# name Sztegon guess Korean, category Czech
# name Tunison guess Japanese, category Dutch
# name Smits guess Korean, category Dutch
# name Qiao guess Korean, category Chinese
# name Yang guess English, category Korean
# name Aitken guess Korean, category Scottish
# name Vamvakidis guess Russian, category Greek
# name Ruda guess English, category Czech
# name Watabe guess Korean, category Japanese
# name Stanek guess Korean, category Polish
# name Wrigglesworth guess Korean, category English
# name Voigt guess Russian, category German
# name Cunningham guess Russian, category Scottish
# name Tsogas guess Japanese, category Greek
# name Sugimura guess Korean, category Japanese
# name Thao guess Japanese, category Vietnamese
# name Thi guess Japanese, category Vietnamese
# name Thorpe guess Japanese, category English
# Accuracy 6.7

# %%
# example from https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
# on how to use CrossEntropyLoss, especially the input dimension
loss = nn.CrossEntropyLoss()
#  input 是 3 个 sample, 然后 class_num 是 5
input = torch.randn(3, 5, requires_grad=True)
#  output 是直接 size 位3 的一个 array， 然后就是class indices的值
target = torch.empty(3, dtype=torch.long).random_(5)
print(f"input {input}")
print(f"input.size() {input.size()}")

print(f"target {target}")
print(f"target.size() {target.size()}")
output = loss(input, target)
output.backward()
print(output)
# Out:
# input tensor([[-0.6925, -0.4816,  0.3532,  0.5015, -0.3637],
#         [-0.9110,  0.0189,  0.1807, -0.3888, -0.8696],
#         [-0.0022, -0.5705, -0.7836, -1.2032, -1.6133]], requires_grad=True)
# input.size() torch.Size([3, 5])
# target tensor([3, 4, 2])
# target.size() torch.Size([3])
# tensor(1.6584, grad_fn=<NllLossBackward0>)
